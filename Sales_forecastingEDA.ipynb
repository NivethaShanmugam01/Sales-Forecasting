# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_absolute_error, mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
from xgboost import XGBRegressor
from sklearn.preprocessing import OneHotEncoder

# %%
features_df = pd.read_csv(r"/content/Features_data_set.csv")
print(features_df.head())
print('--------------------------------------------------------------------------------------')
stores_df = pd.read_csv(r"/content/stores_data_set.csv")
print(stores_df.head())
print('--------------------------------------------------------------------------------------')
df = pd.read_csv(r"/content/sales_data_set.csv")
print(df.head())
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  12/02/2010        38.51       2.548        NaN        NaN
# 2      1  19/02/2010        39.93       2.514        NaN        NaN
# 3      1  26/02/2010        46.63       2.561        NaN        NaN
# 4      1  05/03/2010        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False
# --------------------------------------------------------------------------------------
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875
# --------------------------------------------------------------------------------------
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  05/02/2010      24924.50      False
# 1      1     1  12/02/2010      46039.49       True
# 2      1     1  19/02/2010      41595.55      False
# 3      1     1  26/02/2010      19403.54      False
# 4      1     1  05/03/2010      21827.90      False

# %%
df = pd.merge(df, features_df.drop(['IsHoliday'], axis = 1), how = 'left', on = ['Store', 'Date'])
df = pd.merge(df, stores_df, how = 'left', on = ['Store'])
df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1  05/02/2010      24924.50      False        42.31       2.572
# 1      1     1  12/02/2010      46039.49       True        38.51       2.548
# 2      1     1  19/02/2010      41595.55      False        39.93       2.514
# 3      1     1  26/02/2010      19403.54      False        46.63       2.561
# 4      1     1  05/03/2010      21827.90      False        46.50       2.625
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
# 1        NaN        NaN        NaN        NaN        NaN  211.242170
# 2        NaN        NaN        NaN        NaN        NaN  211.289143
# 3        NaN        NaN        NaN        NaN        NaN  211.319643
# 4        NaN        NaN        NaN        NaN        NaN  211.350143
#
#    Unemployment Type    Size
# 0         8.106    A  151315
# 1         8.106    A  151315
# 2         8.106    A  151315
# 3         8.106    A  151315
# 4         8.106    A  151315

# %%
df.shape
# Out:
# (421570, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 421570 entries, 0 to 421569
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
#  5   Temperature   421570 non-null  float64
#  6   Fuel_Price    421570 non-null  float64
#  7   MarkDown1     150681 non-null  float64
#  8   MarkDown2     111248 non-null  float64
#  9   MarkDown3     137091 non-null  float64
#  10  MarkDown4     134967 non-null  float64
#  11  MarkDown5     151432 non-null  float64
#  12  CPI           421570 non-null  float64
#  13  Unemployment  421570 non-null  float64
#  14  Type          421570 non-null  object
#  15  Size          421570 non-null  int64
# dtypes: bool(1), float64(10), int64(3), object(2)
# memory usage: 51.9+ MB

# %%
df.isnull().sum()
# Out:
# Store                0
# Dept                 0
# Date                 0
# Weekly_Sales         0
# IsHoliday            0
# Temperature          0
# Fuel_Price           0
# MarkDown1       270889
# MarkDown2       310322
# MarkDown3       284479
# MarkDown4       286603
# MarkDown5       270138
# CPI                  0
# Unemployment         0
# Type                 0
# Size                 0
# dtype: int64

# %%
df.fillna(0,inplace = True)

# %%
df.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# Temperature     0
# Fuel_Price      0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# Type            0
# Size            0
# dtype: int64

# %%
# summary statistics of the dataset
df[['Weekly_Sales','Fuel_Price', 'Temperature', 'CPI', 'Size']].describe()
# Out:
#         Weekly_Sales     Fuel_Price    Temperature            CPI  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean    15981.258123       3.361027      60.090059     171.201947
# std     22711.183519       0.458515      18.447931      39.159276
# min     -4988.940000       2.472000      -2.060000     126.064000
# 25%      2079.650000       2.933000      46.680000     132.022667
# 50%      7612.030000       3.452000      62.090000     182.318780
# 75%     20205.852500       3.738000      74.280000     212.416993
# max    693099.360000       4.468000     100.140000     227.232807
#
#                 Size
# count  421570.000000
# mean   136727.915739
# std     60980.583328
# min     34875.000000
# 25%     93638.000000
# 50%    140167.000000
# 75%    202505.000000
# max    219622.000000

# %%
temp = pd.DataFrame(df.groupby('Type')['Store'].nunique()).reset_index()
print(temp)
plt.figure(figsize = (3,3))
plt.pie(temp['Store'], labels = temp['Type'], autopct = '%.0f%%')
plt.show()
# Out:
#   Type  Store
# 0    A     22
# 1    B     17
# 2    C      6

# %%
plt.figure(figsize = (5,4))
plt.title('size distribution of stores for each store type')
sns.boxplot(x = 'Type', y ='Size', data = df, showfliers = False)
# Out:
# <Axes: title={'center': 'size distribution of stores for each store type'}, xlabel='Type', ylabel='Size'>

# %%
plt.figure(figsize = (5,4))
plt.title('Distribution of weekly sales based on store type')
sns.boxplot(x = 'Type', y ='Weekly_Sales', data = df, showfliers = False)
# Out:
# <Axes: title={'center': 'Distribution of weekly sales based on store type'}, xlabel='Type', ylabel='Weekly_Sales'>

# %%
# impact of holidays on weekly sales
plt.figure(figsize = (5,4))
sns.boxplot(x = 'IsHoliday', y ='Weekly_Sales', data = df, showfliers = False)
# Out:
# <Axes: xlabel='IsHoliday', ylabel='Weekly_Sales'>

# %%
feature_cols = ['Weekly_Sales', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4',
       'MarkDown5', 'CPI', 'Unemployment', 'Size']
plt.figure(figsize = (10,4))
plt.title('Correlation Matrix')
sns.heatmap(df[feature_cols].corr(),cmap="Reds", annot = True)
# Out:
# <Axes: title={'center': 'Correlation Matrix'}>

# %%
# create year, month, and date
df['Date'] = pd.to_datetime(df['Date'])
df['month_date'] = df['Date'].apply(lambda i : i.month)
df['day_date'] = df['Date'].apply(lambda i : i.day)
df['year_date'] = df['Date'].apply(lambda i : i.year)

# one hot encoding
cols_to_encode = ['Type', 'IsHoliday']
df = pd.get_dummies(data = df, columns = cols_to_encode, drop_first = True)

# Standard Scaler
standard_scaler = StandardScaler()
feature_cols = ['Temperature', 'Fuel_Price', 'MarkDown1','MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'Size']
transformed_features = standard_scaler.fit_transform(df[feature_cols])

df[feature_cols] = transformed_features

# split data into train and test
feature_cols  = df.columns.tolist()
feature_cols = [i for i in feature_cols if i not in ['Date', 'Weekly_Sales']]

x_train, x_test, y_train, y_test = train_test_split(df[feature_cols], df['Weekly_Sales'], test_size = 0.2, random_state = 1234)
# Out:
# <ipython-input-53-e677b764d5ca>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
x_train
# Out:
#         Store  Dept  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 198734     21     9    -0.454255   -1.286823  -0.427943  -0.173069  -0.084662
# 45753       5    52     0.665113   -0.189801  -0.427943  -0.173069  -0.084662
# 12660       2    19     0.799003   -1.166871  -0.427943  -0.173069  -0.084662
# 103944     11    49     1.592047    0.700030  -0.427943  -0.173069  -0.084662
# 21856       3    10     0.837490   -0.165811  -0.427943  -0.173069  -0.084662
# ...       ...   ...          ...         ...        ...        ...        ...
# 294543     31     6     1.175740   -0.032772   0.586504  -0.167955  -0.083879
# 344728     36    81    -0.050957    0.189686  -0.427943  -0.173069  -0.084662
# 220532     23    28     0.497072   -0.992394  -0.427943  -0.173069  -0.084662
# 384053     41    24     0.174000   -1.267195  -0.427943  -0.173069  -0.084662
# 165158     17    74    -1.976379   -0.534393   0.506975   2.481791  -0.081720
#
#         MarkDown4  MarkDown5       CPI  Unemployment      Size  month_date  \
# 198734  -0.278117  -0.395181  1.030283      0.108792  0.056396          11
# 45753   -0.278117  -0.395181  1.193124     -0.891050 -1.670254          10
# 12660   -0.278117  -0.395181  0.997846      0.128649  1.075411           5
# 103944  -0.278117  -0.395181  1.216625     -0.211072  1.160552           7
# 21856   -0.278117  -0.395181  1.257123     -0.409645 -1.628978           7
# ...           ...        ...       ...           ...       ...         ...
# 294543   0.649632   1.732861  1.282947     -0.573870  1.099074           6
# 344728  -0.278117  -0.395181  1.063841      0.233303 -1.587686          11
# 220532  -0.278117  -0.395181 -0.993585     -1.355282 -0.363967           5
# 384053  -0.278117  -0.395181  0.490150     -0.335582  0.977248          10
# 165158   0.824095   1.032872 -1.042335     -0.835772 -0.713997          10
#
#         day_date  year_date  Type_B  Type_C  IsHoliday_True
# 198734        19       2010       1       0               0
# 45753         14       2011       1       0               0
# 12660         21       2010       0       0               0
# 103944        29       2011       0       0               0
# 21856         10       2011       1       0               0
# ...          ...        ...     ...     ...             ...
# 294543        22       2012       0       0               0
# 344728         3       2011       0       0               0
# 220532        28       2010       1       0               0
# 384053         9       2010       0       0               1
# 165158         2       2012       1       0               1
#
# [337256 rows x 18 columns]

# %%
X = df[['Store', 'Dept', 'Temperature', 'Fuel_Price', 'CPI', 'Unemployment']]
# Extract target variable
y = df['Weekly_Sales']

# %%
decision_tree_regressor = DecisionTreeRegressor(random_state = 1234)
decision_tree_regressor.fit(x_train, y_train)
y_pred = decision_tree_regressor.predict(x_test)

print(f'MAE is - {metrics.mean_absolute_error(y_test, y_pred)}')
print(f'RMSE is - {np.sqrt(metrics.mean_squared_error(y_test, y_pred))}')
print(f'Accuracy Score is - {decision_tree_regressor.score(x_test, y_test)}')
# Out:
# MAE is - 2077.517279929786
# RMSE is - 5899.605502055716
# Accuracy Score is - 0.9333310231036376

# %%
rf_regressor = RandomForestRegressor(n_estimators = 400, max_depth = 15, random_state = 1234, n_jobs = 5)
rf_regressor.fit(x_train, y_train)
y_pred = rf_regressor.predict(x_test)

print(f'MAE is - {metrics.mean_absolute_error(y_test, y_pred)}')
print(f'RMSE is - {np.sqrt(metrics.mean_squared_error(y_test, y_pred))}')
print(f'Accuracy Score is - {rf_regressor.score(x_test, y_test)}')
# Out:
# MAE is - 2094.3344685658
# RMSE is - 5038.956971653642
# Accuracy Score is - 0.9513638548091641

# %%
xgb_regressor = XGBRegressor(objective = 'reg:linear', n_estimators = 500, max_depth = 6, nthread = 4, learning_rate = 0.5, random_state = 1234)
xgb_regressor.fit(x_train, y_train)
y_pred = xgb_regressor.predict(x_test)

print(f'MAE is - {metrics.mean_absolute_error(y_test, y_pred)}')
print(f'RMSE is - {np.sqrt(metrics.mean_squared_error(y_test, y_pred))}')
print(f'Accuracy Score is - {xgb_regressor.score(x_test, y_test)}')
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [11:08:32] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# MAE is - 2087.6737514513097
# RMSE is - 4149.89524964932
# Accuracy Score is - 0.9670122939788532

# %%
models = ['decision_tree_regressor', 'rf_regressor', 'xgb_regressor']
accuracy_scores = [0.94, 0.95, 0.96]
plt.figure(figsize = (5,4))
plt.bar(models, accuracy_scores, color=['red', 'blue', 'green'])
plt.xlabel('Models')
plt.ylabel('Accuracy Score')
plt.title('Model Comparison - Accuracy Scores')
plt.show()

# %%
# scatter plot between observed and predicted values of weekly sales from XGBoost regressor
plt.figure(figsize = (9,4))
sns.scatterplot(x = y_test, y = y_pred)
# Out:
# <Axes: xlabel='Weekly_Sales'>

# %%
#saving a model
import pickle
pickle.dump(xgb_regressor,open('model.pkl', 'wb'))
with open('scaler.pkl', 'wb') as f:
  pickle.dump(standard_scaler, f)
